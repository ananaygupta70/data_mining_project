# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\NITJ\\Desktop\\DMMidTerm_TeamId_37\\Data\\11.19_Investment_during_the_year_1970_71_in_different_undertakings.csv")
#Dropping rows and columns with excess NA(Data Reduction)
df=df.dropna(thresh=len(df)-30,axis=1)
df=df[pd.notnull(df['Total (Col. 8)'])]
df
# Out:
#                    Category (Col. 1)             Sub-Category (Col. 2)  \
# 0             A. Passenger Transport                 (i) City Services
# 1             A. Passenger Transport                 (i) City Services
# 2             A. Passenger Transport                 (i) City Services
# 3             A. Passenger Transport                 (i) City Services
# 4             A. Passenger Transport                 (i) City Services
# 5             A. Passenger Transport                 (i) City Services
# 6             A. Passenger Transport                 (i) City Services
# 7             A. Passenger Transport                 (i) City Services
# 10            A. Passenger Transport            (ii) District Services
# 11            A. Passenger Transport            (ii) District Services
# 12            A. Passenger Transport            (ii) District Services
# 13            A. Passenger Transport            (ii) District Services
# ...
