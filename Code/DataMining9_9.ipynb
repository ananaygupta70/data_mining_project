# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\NITJ\\Desktop\\DMMidTerm_TeamId_37\\Data\\9.9_Seat_Utilisation_per_day_during_1971_Service_wise_and_Undertaking_wise.csv",header= 0,encoding= 'unicode_escape')
df
# Out:
#      Categoy (Col. 1) Nature of Service/ Undertaking (Col. 2)  \
# 0    A. City Services                        A. City Services
# 1    A. City Services                           BESTU, Bombay
# 2    A. City Services                            TSTD, Madras
# 3    A. City Services                              DTC, Delhi
# 4    A. City Services                         AMTS, Ahmedabad
# ..                ...                                     ...
# 206               NaN                                     NaN
# 207               NaN                                     NaN
# 208               NaN                                     NaN
# 209               NaN                                     NaN
# 210               NaN                                     NaN
#
#      January (Col. 3)  February (Col. 4)  March (Col. 5)  April (Col. 6)  \
# 0                21.7               20.2            20.8            21.2
# ...

# %%
#Drpping rows and columns which are having excess NA's(Data Reduction)
df=df.dropna(thresh=len(df)-200,axis=1)

# %%
# Out:
#      Categoy (Col. 1) Nature of Service/ Undertaking (Col. 2)  \
# 0    A. City Services                        A. City Services
# 1    A. City Services                           BESTU, Bombay
# 2    A. City Services                            TSTD, Madras
# 3    A. City Services                              DTC, Delhi
# 4    A. City Services                         AMTS, Ahmedabad
# ..                ...                                     ...
# 206               NaN                                     NaN
# 207               NaN                                     NaN
# 208               NaN                                     NaN
# 209               NaN                                     NaN
# 210               NaN                                     NaN
#
#      January (Col. 3)  February (Col. 4)  March (Col. 5)  April (Col. 6)  \
# 0                21.7               20.2            20.8            21.2
# ...

# %%
df=df.dropna(axis=0, how='any', thresh=3, subset=None, inplace=False)

# %%
df
# Out:
#            Categoy (Col. 1) Nature of Service/ Undertaking (Col. 2)  \
# 0          A. City Services                        A. City Services
# 1          A. City Services                           BESTU, Bombay
# 2          A. City Services                            TSTD, Madras
# 3          A. City Services                              DTC, Delhi
# 4          A. City Services                         AMTS, Ahmedabad
# 5          A. City Services                       MySRTC, Bangalore
# 6          A. City Services                       APSRTC, Hyderabad
# 7          A. City Services                         CTU, Chandigarh
# 8          A. City Services                          CSTC, Calcutta
# 9          A. City Services                             PMTS, Poona
# 10         A. City Services                        J&KGTU, Srinagar
# 11         A. City Services                          KMTS, Kolhapur
# 12         A. City Services                          SMTS, Sholapur
# ...

# %%
#Replacing NA with mean of the columns(data Cleaning)
df=df.fillna(df.mean(),inplace=False)

# %%
df
# Out:
#            Categoy (Col. 1) Nature of Service/ Undertaking (Col. 2)  \
# 0          A. City Services                        A. City Services
# 1          A. City Services                           BESTU, Bombay
# 2          A. City Services                            TSTD, Madras
# 3          A. City Services                              DTC, Delhi
# 4          A. City Services                         AMTS, Ahmedabad
# 5          A. City Services                       MySRTC, Bangalore
# 6          A. City Services                       APSRTC, Hyderabad
# 7          A. City Services                         CTU, Chandigarh
# 8          A. City Services                          CSTC, Calcutta
# 9          A. City Services                             PMTS, Poona
# 10         A. City Services                        J&KGTU, Srinagar
# 11         A. City Services                          KMTS, Kolhapur
# 12         A. City Services                          SMTS, Sholapur
# ...
